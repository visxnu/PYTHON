# %% [markdown]
# Get a user input value,and check if it is 'postive','negative'or 'zero.

# %%
a=int(input("Enter the number="))

if a>0:
  print("Positive")
elif a==0:
  print("Zero")
else:
  print("Negative")
# Out:
# Enter the number=5
# Positive

# %% [markdown]
# Check if any element is multiple of 5 and postive.else print doesn't satifying condition

# %%
a=[25,32,45,77,0,-5,-20]

for x in a:
  if x%5==0 and x>0:
    print(x,"Is the multiple of 5 and postive")
  else:
    print(x,"Not satisfying condtion")
# Out:
# 25 Is the multiple of 5 and postive
# 32 Not satisfying condtion
# 45 Is the multiple of 5 and postive
# 77 Not satisfying condtion
# 0 Not satisfying condtion
# -5 Not satisfying condtion
# -20 Not satisfying condtion
