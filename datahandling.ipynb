# %%
f=open("/content/sample_data/datahandling","w")
f.write("It is one\n of method in datahandling \nis know as write mode")
f=open("/content/sample_data/datahandling")
print(f.readline())
print(f.readline())
print(f.readline())
# Out:
# It is one
#
#  of method in datahandling
#
# is know as write mode

# %%
f=open("/content/sample_data/datahandling","w")
f.write("i am vishnu \ni am from kasaragod \ni am beautiful")
f=open("/content/sample_data/datahandling","a")
f.write("\ni am single and ready to mingle")
f=open("/content/sample_data/datahandling")
print(f.read())
# Out:
# i am vishnu
# i am from kasaragod
# i am beautiful
# i am single and ready to mingle

# %%
newfile=open("file1","x")

# %%
import os
os.remove("file1")
