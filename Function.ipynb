# %%
def my_function():
  a=("enter the number")
  print(a)
my_function()
# Out:
# enter the number

# %%
a=int(input("enter the range"))
def even(a):
  for i in range(1,a):
    if i%2==0:
      print(i)
even(a)
# Out:
# enter the range10
# 2
# 4
# 6
# 8

# %%
a=int(input("enter the range"))
def sum(a):
  s=0
  for i in range(a):
    s=s+i
  print(s)

sum(a)
# Out:
# enter the range5
# 10

# %%
def mul():
  a=int(input("Enter the range "))
  m=1
  for i in range(1,a):
    m=m*i
  print(m)
mul()
# Out:
# Enter the range 5
# 24

# %%
def vowel(a):
  x="aeiouAEIOU"
  c=0
  for i in a:
    if i in x:
      c=c+1
  print(c)
a=input("Enter the string= ")
vowel(a)
# Out:
# Enter the string= abhi
# 2
