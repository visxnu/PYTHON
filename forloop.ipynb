# %%
a="Hello world"
for i in a:
  print(i,end="")
# Out:
# Hello world

# %%
fruits=["apple","orange","mango"]
for i in fruits:
  print(i)
  if i=="orange":
    break
# Out:
# apple
# orange

# %%
fruits=["apple","orange","mango"]
for i in fruits:
  if i=="orange":
    continue
  print(i)
# Out:
# apple
# mango

# %%
for i in range(6):
  print("Hello")
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello

# %%
for i in range(1,11,2):
  print(i)
# Out:
# 1
# 3
# 5
# 7
# 9
