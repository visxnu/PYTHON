# %% [markdown]
# generate list 'L' of 50 random numbers between 1 & 100

# %%
import random
a=[]
for i in range (50):
 a.append(random.randrange(0,100))
print(a)
# Out:
# [8, 46, 12, 38, 0, 36, 21, 41, 43, 11, 22, 38, 75, 60, 78, 24, 52, 49, 18, 8, 3, 70, 50, 95, 84, 1, 41, 20, 31, 72, 5, 4, 85, 75, 50, 57, 83, 24, 99, 77, 6, 15, 59, 13, 69, 77, 50, 92, 64, 26]

# %%
import random
print(random.randrange(1,100))
# Out:
# 88

# %%
import random
for i in range(50):
 print(random.randrange(1,100))
# Out:
# 91
# 61
# 23
# 84
# 10
# 21
# 11
# 42
# 37
# 60
# 26
# 3
# 93
# 81
# 32
# 5
# 36
# 74
# 89
# 47
# 86
# 77
# 20
# 22
# 40
# 56
# 83
# 94
# 85
# 39
# 59
# 51
# 87
# 7
# 9
# 93
# 58
# 60
# 63
# 40
# 67
# 29
# 18
# 46
# 20
# 69
# 66
# 52
# 51
# 47

# %%
u=[1,2,3,4]
u.remove(4)
print(u)
# Out:
# [1, 2, 3]

# %%
u=[1,2,3,4]
u.pop()
print(u)
# Out:
# [1, 2, 3]

# %%
u=[1,2,3,4]
del u[3]
print(u)
# Out:
# [1, 2, 3]

# %%
first=[12,13,14,15]
second=[16,17,18,19]
newf=first.copy()
news=second.copy()
newf.insert(2,100)
news.insert(0,200)
print(newf)
print(news)
# Out:
# [12, 13, 100, 14, 15]
# [200, 16, 17, 18, 19]

# %% [markdown]
# Homework

# %%
a=[]
a.append(1)
a.append(2)
a.append(3)
print(a)
# Out:
# [1, 2, 3]

# %%
a=["orange","yellow","red"]
a.insert(1,"white")
print(a)
# Out:
# ['orange', 'white', 'yellow', 'red']

# %%
a=[1,2,3,4,5]
b=[6,7,8,9,0]
a.extend(b)
print(a)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9, 0]

# %%
a=["dog","cat","rat"]
a.remove("cat")
print(a)
# Out:
# ['dog', 'rat']

# %%
a=["orange","apple","mango"]
a.pop()
print(a)
# Out:
# ['orange', 'apple']

# %%
car=["bmw","benz","audi"]
del car[1]
print(car)
# Out:
# ['bmw', 'audi']

# %%
city=["delhi","mumbai","kolkata"]
city.clear()
print(city)
# Out:
# []

# %%
name=["arjun","praji","dhanu"]
for i in name:
  print(i)
# Out:
# arjun
# praji
# dhanu

# %%
a=[1,3,43,56,22,53,76]
for i in range(len(a)):
  print(f"index= {i}:{a[i]}")
# Out:
# index= 0:1
# index= 1:3
# index= 2:43
# index= 3:56
# index= 4:22
# index= 5:53
# index= 6:76

# %%
sq=[i **2for i in range(1,6)]
print(sq)
# Out:
# [1, 4, 9, 16, 25]
