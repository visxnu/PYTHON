# %% [markdown]
# Importing keyword

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
print("* * *")
print("* * *")
print("* * *")
# Out:
# * * *
# * * *
# * * *

# %%
a= 512-282
b= 47.48+5
print(a)
print(b)
print(a/b)
# Out:
# 230
# 52.48
# 4.382621951219512

# %%
import random

print(random.randrange(1,10))
# Out:
# 5

# %%
from math import sin,cos,tan,pi
print(cos(1)/sin(1))
print(sin(90))
print(tan(90))
# Out:
# 0.6420926159343308
# 0.8939966636005579
# -1.995200412208242

# %%
print(round(3.44443,2))
print(round(34.44443,-3))
print(round(3.44443,3))
print(round(3.44443,-6))
print(abs(-6))
# Out:
# 3.44
# 0.0
# 3.444
# 0.0
# 6

# %%
from math  import pi
print(pi)
# Out:
# 3.141592653589793

# %%
round(3.34556,3)
# Out:
# 3.346

# %%
import math
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
import random
for i in range(0,51):



  print(random.randrange(3,6))
# Out:
# 5
# 5
# 3
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 5
# 3
# 3
# 4
# 3
# 4
# 5
# 5
# 4
# 3
# 4
# 5
# 4
# 4
# 3
# 4
# 4
# 4
# 3
# 5
# 5
# 5
# 3
# 5
# 4
# 3
# 3
# 3
# 3
# 4
# 4
# 3
# 5
# 4
# 3
# 4
# 5
# 4
# 4
# 5
# 3

# %%
a="22"
b=int(a)
print(a)
print(type(b))
# Out:
# 22
# <class 'int'>

# %%
a=32
b=str(a)
print(a)
print(type(b))
# Out:
# 32
# <class 'str'>

# %%
a=2.4
b=int(a)
print(a)
print(type(b))

print(type(a))
# Out:
# 2.4
# <class 'int'>
# <class 'float'>
